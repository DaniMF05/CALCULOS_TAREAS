# %% [markdown]
# # TAREA 4 - CALCULOS
#
# **Nombre:** Joshua Daniel Menendez Farias
#
# **Fecha de entrega:** 19 - 05 - 2025

# %%
# EJERCICIO 1

import math

def f(x: float) -> float:
    return ( x**3 - 7*x**2 + 14*x -6)



def biseccion(a: float, b: float, tol: float = 1e-2, max_iter: int = 500):
    if f(a) * f(b) >= 0:
        print("El método de bisección no es aplicable: f(a) y f(b) deben tener signos opuestos.")
        return None
    
    print(f(a))
    print(f(b))

    iteracion = 0
    while (b - a) / 2 > tol and iteracion < max_iter:
        c = (a + b) / 2
        fc = f(c)
        fb = f(b)
        minerror = abs(b-c)
        difer = fc * fb


        #print(f" {a:.6f}, {b:.6f}, {c:.6f}, {fc:.6f}, {minerror:.6f}, {difer:.6f}")
        print(f"{iteracion:<6},{a:<15.8f},{b:<15.8f},{c:<15.8f},{fc:<15.8f},{minerror:<15.8f},{difer:<15.8f}")
        if abs(fc) < tol:
            return c
        elif f(a) * fc < 0:
            b = c
        else:
            a = c
        iteracion += 1

    return (a + b) / 2  # Valor aproximado de la raíz

biseccion(0,1)
biseccion(3.2,4)
# Out:
# -6
# 2
# 0     ,0.00000000     ,1.00000000     ,0.50000000     ,-0.62500000    ,0.50000000     ,-1.25000000
# 1     ,0.50000000     ,1.00000000     ,0.75000000     ,0.98437500     ,0.25000000     ,1.96875000
# 2     ,0.50000000     ,0.75000000     ,0.62500000     ,0.25976562     ,0.12500000     ,0.25570679
# 3     ,0.50000000     ,0.62500000     ,0.56250000     ,-0.16186523    ,0.06250000     ,-0.04204702
# 4     ,0.56250000     ,0.62500000     ,0.59375000     ,0.05404663     ,0.03125000     ,0.01403946
# 5     ,0.56250000     ,0.59375000     ,0.57812500     ,-0.05262375    ,0.01562500     ,-0.00284414
# -0.11199999999999477
# 2
# 0     ,3.20000000     ,4.00000000     ,3.60000000     ,0.33600000     ,0.40000000     ,0.67200000
# 1     ,3.20000000     ,3.60000000     ,3.40000000     ,-0.01600000    ,0.20000000     ,-0.00537600
# 2     ,3.40000000     ,3.60000000     ,3.50000000     ,0.12500000     ,0.10000000     ,0.04200000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# Rango de x: evitamos los puntos donde tan(x) no está definida
x = np.linspace(0, 4, 1000)
y_f1 = x
y_f2 = np.sin(x)
# Crear la figura
plt.figure(figsize=(10, 6))

# Graficar las funciones
plt.plot(x, y_f1, label='f1', color='blue')
plt.plot(x, y_f2, label='f2', color='red')


# Limitar el eje y para evitar saltos extremos de tan(x)


# Etiquetas y detalles
plt.title('Grafica de f1 y f2')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

# Mostrar la gráfica
plt.show()

# %%
# EJERCICIO 2A

import math

def f(x: float) -> float:
    return ( 2* math.sin(x) - x)



def biseccion(a: float, b: float, tol: float = 1e-2, max_iter: int = 500):
    if f(a) * f(b) >= 0:
        print("El método de bisección no es aplicable: f(a) y f(b) deben tener signos opuestos.")
        return None
    
    print(f(a))
    print(f(b))

    iteracion = 0
    while (b - a) / 2 > tol and iteracion < max_iter:
        c = (a + b) / 2
        fc = f(c)
        fb = f(b)
        minerror = abs(b-c)
        difer = fc * fb


        #print(f" {a:.6f}, {b:.6f}, {c:.6f}, {fc:.6f}, {minerror:.6f}, {difer:.6f}")
        print(f"{iteracion:<6},{a:<15.8f},{b:<15.8f},{c:<15.8f},{fc:<15.8f},{minerror:<15.8f},{difer:<15.8f}")
        if abs(fc) < tol:
            return c
        elif f(a) * fc < 0:
            b = c
        else:
            a = c
        iteracion += 1

    return (a + b) / 2  # Valor aproximado de la raíz

biseccion(1,3)
# Out:
# 0.682941969615793
# -2.7177599838802657
# 0     ,1.00000000     ,3.00000000     ,2.00000000     ,-0.18140515    ,1.00000000     ,0.49301565
# 1     ,1.00000000     ,2.00000000     ,1.50000000     ,0.49498997     ,0.50000000     ,-0.08979373
# 2     ,1.50000000     ,2.00000000     ,1.75000000     ,0.21797189     ,0.25000000     ,-0.03954122
# 3     ,1.75000000     ,2.00000000     ,1.87500000     ,0.03317156     ,0.12500000     ,-0.00601749
# 4     ,1.87500000     ,2.00000000     ,1.93750000     ,-0.07047144    ,0.06250000     ,0.01278388
# 5     ,1.87500000     ,1.93750000     ,1.90625000     ,-0.01772788    ,0.03125000     ,0.00124931
# 6     ,1.87500000     ,1.90625000     ,1.89062500     ,0.00795360     ,0.01562500     ,-0.00014100
# 1.890625

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

def f(x:float) -> float:
    return (2 * (math.sin(x)))


xs = np.linspace(-10, 10, 1000)
ys = []

for x in xs:
    ys.append(f(x))

plt.plot(xs, ys, label="f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Plot of f(x)")
plt.grid(True)
plt.legend()
plt.axhline(0, color='black', lw=0.5, ls='--')

# %%
import math

def f(x: float) -> float:
    return ( (math.tan(x) - x))



def biseccion(a: float, b: float, tol: float = 1e-5, max_iter: int = 500):
    if f(a) * f(b) >= 0:
        print("El método de bisección no es aplicable: f(a) y f(b) deben tener signos opuestos.")
        return None
    
    print(f(a))
    print(f(b))

    iteracion = 0
    while (b - a) / 2 > tol and iteracion < max_iter:
        c = (a + b) / 2
        fc = f(c)
        fb = f(b)
        minerror = abs(b-c)
        difer = fc * fb


        #print(f" {a:.6f}, {b:.6f}, {c:.6f}, {fc:.6f}, {minerror:.6f}, {difer:.6f}")
        print(f"{iteracion:<6},{a:<15.8f},{b:<15.8f},{c:<15.8f},{fc:<15.8f},{minerror:<15.8f},{difer:<15.8f}")
        if abs(fc) < tol:
            return c
        elif f(a) * fc < 0:
            b = c
        else:
            a = c
        iteracion += 1

    return (a + b) / 2  # Valor aproximado de la raíz

biseccion(1, 5 )
# Out:
# 0.5574077246549023
# -8.380515006246586
# 0     ,1.00000000     ,5.00000000     ,3.00000000     ,-3.14254654    ,2.00000000     ,26.33615846
# 1     ,1.00000000     ,3.00000000     ,2.00000000     ,-4.18503986    ,1.00000000     ,13.15168255
# 2     ,1.00000000     ,2.00000000     ,1.50000000     ,12.60141995    ,0.50000000     ,-52.73744481
# 3     ,1.50000000     ,2.00000000     ,1.75000000     ,-7.27037992    ,0.25000000     ,30.42682980
# 4     ,1.50000000     ,1.75000000     ,1.62500000     ,-20.05586276   ,0.12500000     ,145.81374196
# 5     ,1.50000000     ,1.62500000     ,1.56250000     ,118.97000572   ,0.06250000     ,-2386.04610761
# 6     ,1.56250000     ,1.62500000     ,1.59375000     ,-45.15211041   ,0.03125000     ,905.56452975
# 7     ,1.56250000     ,1.59375000     ,1.57812500     ,-138.02602884  ,0.01562500     ,6232.16649332
# 8     ,1.56250000     ,1.57812500     ,1.57031250     ,2065.28487725  ,0.00781250     ,-285063.07003553
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(x:float) -> float:
    return (math.tan(x))

# Crear valores de x evitando los puntos donde la tangente tiende a infinito
xs = np.linspace(-2*np.pi, 2*np.pi, 1000)
xs = x[np.abs(np.cos(x)) > 0.01]  # Eliminar valores cercanos a las asíntotas

# Calcular tan(x)
ys = []

for x in xs:
    ys.append(f(x))

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.plot(xs, ys, label='tan(x)', color='purple')

# Dibujar líneas verticales en las asíntotas (donde cos(x) = 0)
for i in range(-2, 3):
    plt.axvline(x=i * np.pi/2, color='gray', linestyle='--', alpha=0.5)

# Configuración de la gráfica
plt.title('Gráfica de la función Tangente')
plt.xlabel('x')
plt.ylabel('tan(x)')
plt.ylim(-10, 10)  # Limitar eje y para mejor visualización
plt.grid(True)
plt.legend()
plt.axhline(0, color='black', linewidth=0.5)  # Eje x
plt.axvline(0, color='black', linewidth=0.5)  # Eje y

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Rango de x: evitamos los puntos donde tan(x) no está definida
x = np.linspace(0, 6, 1000)
y_lineal = x
y_tan = np.tan(x)

# Crear la figura
plt.figure(figsize=(10, 6))

# Graficar las funciones
plt.plot(x, y_lineal, label='y = x', color='blue')
plt.plot(x, y_tan, label='y = tan(x)', color='red')

# Añadir líneas verticales para las asíntotas
for k in range(-2, 3):
    if k % 2 != 0:
        plt.axvline(x=k * np.pi / 2, color='gray', linestyle='--', linewidth=0.7)

# Limitar el eje y para evitar saltos extremos de tan(x)
plt.ylim(-10, 10)

# Etiquetas y detalles
plt.title('Gráficas de y = x y y = tan(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(x:float) -> float:
    return (math.tan(x) - x)

# Crear valores de x evitando los puntos donde la tangente tiende a infinito
xs = np.linspace(-2*np.pi, 2*np.pi, 1000)

# Calcular tan(x)
ys = []

for x in xs:
    ys.append(f(x))

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.plot(xs, ys, label='tan(x)', color='purple')

# Dibujar líneas verticales en las asíntotas (donde cos(x) = 0)
for i in range(-2, 3):
    plt.axvline(x=i * np.pi/2, color='gray', linestyle='--', alpha=0.5)

# Configuración de la gráfica
plt.title('Gráfica de la función Tangente')
plt.xlabel('x')
plt.ylabel('tan(x)')
plt.ylim(-10, 10)  # Limitar eje y para mejor visualización
plt.grid(True)
plt.legend()
plt.axhline(0, color='black', linewidth=0.5)  # Eje x
plt.axvline(0, color='black', linewidth=0.5)  # Eje y

plt.show()

# %%
def f(x: float) -> float:
    return ( (math.tan(x) - x))



def biseccion(a: float, b: float, tol: float = 1e-5, max_iter: int = 500):
    if f(a) * f(b) >= 0:
        print("El método de bisección no es aplicable: f(a) y f(b) deben tener signos opuestos.")
        return None
    
    print(f(a))
    print(f(b))

    iteracion = 0
    while (b - a) / 2 > tol and iteracion < max_iter:
        c = (a + b) / 2
        fc = f(c)
        fb = f(b)
        minerror = abs(b-c)
        difer = fc * fb


        #print(f" {a:.6f}, {b:.6f}, {c:.6f}, {fc:.6f}, {minerror:.6f}, {difer:.6f}")
        print(a,",", b,",",c,",",fc,",",minerror,",",difer)

        if abs(fc) < tol:
            return c
        elif f(a) * fc < 0:
            b = c
        else:
            a = c
        iteracion += 1

    return (a + b) / 2  # Valor aproximado de la raíz

biseccion(2, 4.6 )
# Out:
# -4.185039863261519
# 4.260174895648046
# 2 , 4.6 , 3.3 , -3.1402542523399677 , 1.2999999999999998 , -13.378032331770754
# 3.3 , 4.6 , 3.9499999999999997 , -2.902889342117835 , 0.6499999999999999 , -12.366816300134671
# 3.9499999999999997 , 4.6 , 4.2749999999999995 , -2.136395891258748 , 0.3250000000000002 , -9.10142014310615
# 4.2749999999999995 , 4.6 , 4.4375 , -0.8917623433612674 , 0.16249999999999964 , -3.7990635480719437
# 4.4375 , 4.6 , 4.51875 , 0.5807912065967704 , 0.08124999999999982 , 2.474272117956699
# 4.4375 , 4.51875 , 4.478125 , -0.28781151597217747 , 0.04062499999999947 , -0.16715839763392662
# 4.478125 , 4.51875 , 4.4984375 , 0.103983658691015 , 0.020312500000000178 , 0.060392794597501354
# 4.478125 , 4.4984375 , 4.48828125 , -0.10109545845494061 , 0.010156249999999645 , -0.010512275647190232
# 4.48828125 , 4.4984375 , 4.493359375 , -0.0010109716402046942 , 0.005078124999999822 , -0.00010512452998134054
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# Rango de x: evitamos los puntos donde tan(x) no está definida
x = np.linspace(-2, 2, 1000)
y_f1 = x**2 - 1
y_f2 = math.e**(1 - x**2)
# Crear la figura
plt.figure(figsize=(10, 6))

# Graficar las funciones
plt.plot(x, y_f1, label='f1', color='blue')
plt.plot(x, y_f2, label='f2', color='red')


# Limitar el eje y para evitar saltos extremos de tan(x)


# Etiquetas y detalles
plt.title('Grafica de f1 y f2')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.legend()

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import math 


def f(x: float) -> float:
    return ( 12.4 - 10 * ((0.5 * math.pi) - math.asin(x)  - x * (1 - x**2 )**0.5 ))



def biseccion(a: float, b: float, tol: float = 1e-2, max_iter: int = 500):
    if f(a) * f(b) >= 0:
        print("El método de bisección no es aplicable: f(a) y f(b) deben tener signos opuestos.")
        print(f(a))
        print(f(b))
        return None
    
    print(f(a))
    print(f(b))

    iteracion = 0
    while (b - a) / 2 > tol and iteracion < max_iter:
        c = (a + b) / 2
        fc = f(c)
        fb = f(b)
        minerror = abs(b-c)
        difer = fc * fb


        #print(f" {a:.6f}, {b:.6f}, {c:.6f}, {fc:.6f}, {minerror:.6f}, {difer:.6f}")
        print(a,",", b,",",c,",",fc,",",minerror,",",difer)

        if abs(fc) < tol:
            return c
        elif f(a) * fc < 0:
            b = c
        else:
            a = c
        iteracion += 1
    
    

    return (a + b) / 2  # Valor aproximado de la raíz

biseccion(0, 1)
# Out:
# -3.3079632679489652
# 12.4
# 0 , 1 , 0.5 , 6.258151506956217 , 0.5 , 77.6010786862571
# 0 , 0.5 , 0.25 , 1.6394538748514567 , 0.25 , 10.259950737486854
# 0 , 0.25 , 0.125 , -0.8144890292067846 , 0.125 , -1.3353171949570641
# 0.125 , 0.25 , 0.1875 , 0.4199467241373078 , 0.0625 , 0.688483284118085
# 0.125 , 0.1875 , 0.15625 , -0.1957259025413176 , 0.03125 , -0.0821944516010443
# 0.15625 , 0.1875 , 0.171875 , 0.11253639384839786 , 0.015625 , 0.04725928994286056
# 0.1640625

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

def f(x:float) -> float:
    return ( 300 - (24.525 * x) + 61.312 * (1 - math.e**(-0.4 *x)))


xs = np.linspace(10, 16, 1000)
ys = []

for x in xs:
    ys.append(f(x))

plt.plot(xs, ys, label="f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Plot of f(x)")
plt.grid(True)
plt.legend()
plt.axhline(0, color='black', lw=0.5, ls='--')

# %%
import numpy as np
import math 


def f(x: float) -> float:
    return ( 300 - (24.525 * x) + 61.312 * (1 - math.e**(-0.4 *x)))



def biseccion(a: float, b: float, tol: float = 1e-2, max_iter: int = 500):
    if f(a) * f(b) >= 0:
        print("El método de bisección no es aplicable: f(a) y f(b) deben tener signos opuestos.")
        print(f(a))
        print(f(b))
        return None
    
    print(f(a))
    print(f(b))

    iteracion = 0
    while (b - a) / 2 > tol and iteracion < max_iter:
        c = (a + b) / 2
        fc = f(c)
        fb = f(b)
        minerror = abs(b-c)
        difer = fc * fb


        #print(f" {a:.6f}, {b:.6f}, {c:.6f}, {fc:.6f}, {minerror:.6f}, {difer:.6f}")
        print(a,",", b,",",c,",",fc,",",minerror,",",difer)

        if abs(fc) < tol:
            return c
        elif f(a) * fc < 0:
            b = c
        else:
            a = c
        iteracion += 1
    
    

    return (a + b) / 2  # Valor aproximado de la raíz

biseccion(0, 100)
# Out:
# 300.0
# -2091.188
# 0 , 100 , 50.0 , -864.9380001263735 , 50.0 , 1808747.9666082708
# 0 , 50.0 , 25.0 , -251.8157835604936 , 25.0 , 217805.04023306904
# 0 , 25.0 , 12.5 , 54.33638299359207 , 12.5 , -13682.758859374466
# 12.5 , 25.0 , 18.75 , -98.5656607089025 , 6.25 , 24820.38908357004
# 12.5 , 18.75 , 15.625 , -22.009485004000396 , 3.125 , 2169.3794312819805
# 12.5 , 15.625 , 14.0625 , 16.208061901004605 , 1.5625 , -356.731095354071
# 14.0625 , 15.625 , 14.84375 , -2.892747694185225 , 0.78125 , 63.66788699552643
# 14.0625 , 14.84375 , 14.453125 , 6.659970627151232 , 0.390625 , -19.265614675033053
# 14.453125 , 14.84375 , 14.6484375 , 1.8841455660188657 , 0.1953125 , -5.450357741610389
# 14.6484375 , 14.84375 , 14.74609375 , -0.5041727034291199 , 0.09765625 , 1.4584444253157178
# 14.6484375 , 14.74609375 , 14.697265625 , 0.6900191512596336 , 0.048828125 , -0.3478888209084363
# 14.697265625 , 14.74609375 , 14.7216796875 , 0.09293132421937855 , 0.0244140625 , -0.04685343696493213
# ...

# %%
import numpy as np
import math 


def f(x: float) -> float:
    return (  math.sin(math.pi * x))



def biseccion(a: float, b: float, tol: float = 1e-4, max_iter: int = 500):
    if f(a) * f(b) >= 0:
        print("El método de bisección no es aplicable: f(a) y f(b) deben tener signos opuestos.")
        print(f(a))
        print(f(b))
        return None
    
    print(f(a))
    print(f(b))

    iteracion = 0
    while (b - a) / 2 > tol and iteracion < max_iter:
        c = (a + b) / 2
        fc = f(c)
        fb = f(b)
        minerror = abs(b-c)
        difer = fc * fb


        #print(f" {a:.6f}, {b:.6f}, {c:.6f}, {fc:.6f}, {minerror:.6f}, {difer:.6f}")
        print(a,",", b,",",c,",",fc,",",minerror,",",difer)

        if abs(fc) < tol:
            return c
        elif f(a) * fc < 0:
            b = c
        else:
            a = c
        iteracion += 1
    
    

    return (a + b) / 2  # Valor aproximado de la raíz

biseccion(-0.5, 2.5)
# Out:
# -1.0
# 1.0
# -0.5 , 2.5 , 1.0 , 1.2246467991473532e-16 , 1.5 , 1.2246467991473532e-16
# 1.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

def f(x:float) -> float:
    return ( math.sin(math.pi * x))


xs = np.linspace(0, math.pi * 3, 1000)
ys = []

for x in xs:
    ys.append(f(x))

plt.plot(xs, ys, label="f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Grafica de f(x)")
plt.grid(True)
plt.legend()
plt.axhline(0, color='black', lw=0.5, ls='--')

# %%
x = 0.25
TOL = 1e-6
n = 0
suma = 0

# Lado derecho de la igualdad
valor_derecho = (1 + 2 * x) / (1 + x + x**2)

# Bucle con potencias explícitas
while True:
    # Potencias del numerador
    pot1 = 2**n
    pot2 = 2**(n+1)

    # Numerador y denominador
    numerador = (2**n) * (x**(pot1)) - (2**(n+1)) * (x**(pot2))
    denominador = 1 - (x**pot1) + (x**pot2)

    # Evitar división por cero
    if abs(denominador) < 1e-12:
        break

    termino = numerador / denominador
    suma += termino
    n += 1

    # Verificar tolerancia
    if abs(suma - valor_derecho) < TOL:
        break

# Resultados
print(f"Número de términos requeridos: {n}")
print(f"Suma aproximada de la serie: {suma}")
print(f"Valor real del lado derecho: {valor_derecho}")
print(f"Diferencia: {abs(suma - valor_derecho)}")
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[11], line 16
#      13 pot2 = 2**(n+1)
#      15 # Numerador y denominador
# ---> 16 numerador = (2**n) * (x**(pot1)) - (2**(n+1)) * (x**(pot2))
#      17 denominador = 1 - (x**pot1) + (x**pot2)
#      19 # Evitar división por cero
#
# OverflowError: int too large to convert to float
